# %%
import numpy as np
import pandas as pd

lowlands_athletes_f = pd.read_csv('./lowlands-females.csv')
lowlands_athletes_m = pd.read_csv('./lowlands-males.csv')

torian_athletes_f = pd.read_csv('./torian-females.csv')
torian_athletes_m = pd.read_csv('./torian-males.csv')

syndicate_athletes_f = pd.read_csv('./syndicate-females.csv')
syndicate_athletes_m = pd.read_csv('./syndicate-males.csv')

# %%
lowlands_athletes_f = lowlands_athletes_f.sort_values(by=['semi-ranking']).reset_index()
lowlands_athletes_m = lowlands_athletes_m.sort_values(by=['semi-ranking']).reset_index()

torian_athletes_f = torian_athletes_f.sort_values(by=['semi-ranking']).reset_index()
torian_athletes_m = torian_athletes_m.sort_values(by=['semi-ranking']).reset_index()

syndicate_athletes_f = syndicate_athletes_f.sort_values(by=['semi-ranking']).reset_index()
syndicate_athletes_m = syndicate_athletes_m.sort_values(by=['semi-ranking']).reset_index()

# %%
syndicate_athletes_f['name'].head()
# Out:
# 0             Alexis Raptis
# 1    Kristi Eramo O'Connell
# 2            Arielle Loewen
# 3               Haley Adams
# 4             Paige Semenza
# Name: name, dtype: object

# %%
predictions = pd.DataFrame(columns=[
    'lowlands_athletes_f',
    'lowlands_athletes_m',
    'syndicate_athletes_f',
    'syndicate_athletes_m',
    'torian_athletes_f',
    'torian_athletes_m'])
predictions.reset_index(drop=True)
predictions['lowlands_athletes_f'] = lowlands_athletes_f['name']
predictions['lowlands_athletes_m'] = lowlands_athletes_m['name']
predictions['syndicate_athletes_f'] = syndicate_athletes_f['name']
predictions['syndicate_athletes_m'] = syndicate_athletes_m['name']
predictions['torian_athletes_m'] = torian_athletes_m['name']
predictions['torian_athletes_f'] = torian_athletes_f['name']
predictions.head(30)
# Out:
#                lowlands_athletes_f        lowlands_athletes_m  \
# 0                  Gabriela Migała  Björgvin Karl Guðmundsson
# 1   Ragnheiður Sara Sigmundsdottir                Lazar Đukić
# 2                    Lucy Campbell                Sam Stewart
# 3                   Matilde Garnes             Fabian Beneito
# 4                    Karin Freyová              Moritz Fiebig
# 5                    Laura Horvath             Uldis Upenieks
# 6         Elena Carratala Sanahuja              Enrico Zenoni
# 7                      Ella Wunger                 Luka Đukić
# 8                  Martyna Krysiak           Adrian Mundwiler
# 9                  Megan Lovegrove                Tiago Luzes
# 10                   Linda Keesman            Victor Ljungdal
# 11                     Oihana Moya                 Kevin Jurs
# 12                   Claudia Gluck                Lucas Heuzé
# 13                Sapphire Goddard          Casper Gammelmark
# ...

# %%
foo = pd.concat([lowlands_athletes_m['name']], ignore_index=True)

# %%
foo.head()
# Out:
# 0    Björgvin Karl Guðmundsson
# 1                  Lazar Đukić
# 2                  Sam Stewart
# 3               Fabian Beneito
# 4                Moritz Fiebig
# Name: name, dtype: object
